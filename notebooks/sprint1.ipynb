# %%
import pandas as pd
import glob
import os

# Adjust path to where you downloaded the data
path = "/home/stardhoom/ids-skripsi/" 
all_files = glob.glob(os.path.join(path, "*.csv"))

print(f"Found {len(all_files)} CSV files.")

if all_files:
    # Read just the header of the first file to count columns
    df = pd.read_csv(all_files[0], nrows=5)
    print(f"\nColumns found: {len(df.columns)}")
    print("Column Names sample:", list(df.columns)[:10])
